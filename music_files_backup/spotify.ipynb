# %%
import spotipy
import webbrowser
import datetime
import requests
import base64
from datetime import datetime
import time
from spotify_auth import re_authenticate, setup_spotify #Works well at least for re_auth
import configparser
import os
import requests
import sys 
from pytesseract import pytesseract
import pandas as pd
import re
import subprocess
import win32gui
from win32con import SW_SHOW, SW_RESTORE
import win32com.client
import win32con
import pyautogui
from thefuzz import fuzz
import random

config = configparser.ConfigParser()

# %%
def get_config_file():
    current_file_path = os.getcwd()
    config_file_path = current_file_path + "\\spotify_config.ini"
    
    return config_file_path


def check_expiration():
    
    config_file_path = get_config_file()
    config.read(config_file_path)
    
    token_expiration = config["TOKENS"]["expires_at"]
    
    if float(token_expiration) < float(time.mktime(datetime.now().timetuple())):
        re_authenticate(config_file_path)
        
        
def create_spotify_connection():
    #Must fix, must be ran twice to reauthenticate
    config_file_path = get_config_file()
    
    if os.path.exists(config_file_path):
        config.read(config_file_path)
        
        #Update tokens if outdated
        check_expiration()
        
        #Connect to spotify
        spotifyObject = spotipy.Spotify(auth=config["TOKENS"]["access_token"])
        
        return spotifyObject
        
    
    else:
        setup_spotify(config_file_path)
        create_spotify_connection()
        

        
### WINDOW MANAGEMENT ###        
def get_open_apps():
    apps = {}
    
    def winEnumHandler( hwnd, ctx,):
        if win32gui.IsWindowVisible( hwnd ):
            #int(hex(hwnd)) converts hex back to int
            apps[win32gui.GetWindowText( hwnd )] = hex(hwnd)

    win32gui.EnumWindows( winEnumHandler, None )
    
    return apps


def get_memory_location(app_name):
    apps = get_open_apps()
    app_name = app_name.lower()

    for app in apps:
        if app_name in app.lower():
            return apps[app]
        
        
def manage_window_placement(application_name, use_hex=False):
    """Given application name function brings 
        it to front of screen and maximizes.
        Works if application was minimized or in the back"""
    #Must check to see premium name
    
    #Get spotify window ID
    if use_hex is False:
        window_id = win32gui.FindWindow(None, application_name) #Change name to apply to any program
        
    else:
        config.read(config_file_path)
        hex_id = config["APPLICATION"]["memory_address"]

        window_id = int(hex_id, 16)

    if window_id:
        if win32gui.GetWindowPlacement(window_id)[1] == 2:
            win32gui.ShowWindow(window_id, SW_RESTORE)
            
        else:
            shell = win32com.client.Dispatch("WScript.Shell")
            shell.SendKeys('%')

            win32gui.SetForegroundWindow(window_id)
            
        #win32gui.SetActiveWindow(window_id) #will set monitor 1 or 2 as the main
        
        win32gui.ShowWindow(window_id, win32con.SW_MAXIMIZE)
        
        return 1
        
    else:
        return -1
        
        
def open_spotify():
    """Opens spotify based on user preference (web or app)"""
    
    config_file_path = get_config_file()
    #Checks what type of spotify to open, webbrowser or application
    config.read(config_file_path)
    spotify_preference = config["SETUP"]["preference"]
    
    spotify_version = "Spotify Free" #Used for later
    
    #Handles application and webbrowser seperatley
    if spotify_preference == "application":

        subprocess.Popen(config["APPLICATION"]["path"], shell=True) #Open Spotify App, does nothing if alreayd open


        #Check if spotify is premium or free and bring it to front of screen and enlarge
        if manage_window_placement("Spotify Free") == -1:
            manage_window_placement("Spotify Premium")
            spotify_version = "Spotify Premium"

        while get_memory_location(spotify_version) is None:
            continue
        
        #Get memory address of application for future use (Check if app is still open and what not)
        print(get_memory_location(spotify_version))
        config["APPLICATION"]["memory_address"] = str(get_memory_location("Spotify Premium"))
        
        #Write new memory address to config file
        with open(config_file_path, 'w') as configfile:
            config.write(configfile)
            
            
def restart_device(client):
    devices = client.devices()['devices']
    
    #Check if we have an active device
    for device in devices:
        if device['is_active'] is True:
            return 1
        
    return devices[0]['id']


#Must add error handling (trying to play song when already playing)
def navbar_controller(action, client):
    if action in ["next", "skip"]:
        client.next_track()
        
    if action in ["back", "previous"]:
        client.previous_track()
        
    if action in ["pause", "stop"]:
        client.pause_playback()
        
    if action in ["resume"]:
        client.start_playback()
        
    if action == "shuffle":
        client.shuffle(True)

    if action == "replay":
        client.previous_track()
        client.next_track()



def get_command_type(command):
    pattern = re.compile(r"(.+) by (.+)")
    match = pattern.search(command)
    
    song_name = match.group(1)
    artist_name = match.group(2)
    
    return song_name, artist_name



def find_best_song(command, track_artist, client):
    tracks = client.search(q=command, type="track")
    
    track_popularity = dict()
    
    for track in tracks['tracks']['items']:
        
        #To get specific song like no flocking by kodak
        artist = track['artists'][0]['name'].lower()
        track_name = track['name'].lower()
        track_id = track['id']
        
        if track_artist == "":
            artist = ""
        
        track_fuzz = fuzz.ratio(command, track_name)
        
        #Temp solution will need to convert to similar structure like playlist one
        #may need to do for album as well
#         if track_fuzz < 50:
#             continue
        
        if track_fuzz < 70 or fuzz.ratio(track_artist, artist):
            if fuzz.partial_ratio(track_artist, artist) < 70:
                continue
            
        track_popularity[(track['popularity'] + track_fuzz)] = track_id
        
        
    return track_popularity[max(track_popularity)]



#Could add functioinality when you say next playlist and it will move to second choice
def playlist_ranker(likes_dict, fuzz_dict):
    likes_rank = sorted(likes_dict.values())[::-1]
    fuzz_rank = sorted(fuzz_dict.values())[::-1]
    
    id_ranks = dict()
    
    for id_ in likes_dict:
        likes = likes_dict[id_]
        l_rank = likes_rank.index(likes) + 1
        
        
        fuzz = fuzz_dict[id_]
        f_rank = fuzz_rank.index(fuzz) + 1
        
        id_ranks[id_] = l_rank + f_rank
        
    return min(id_ranks, key=id_ranks.get)


#may be able to merge with best song function but not sure after adding the ranking stuff
#This may need to be the standard for album and song searching
#the playlist search is the perfect example
def find_best_playlist(command, client, spotify_enabled=False, spotify_iter=0):
    playlists = client.search(q=command, type="playlist")
    
    playlist_likes = dict()
    playlist_fuzz = dict()

    #Loop through all playlist
    for playlist in playlists['playlists']['items']:
        
        playlist_name = playlist['name'].lower()
        playlist_id = playlist['id']
        playlist_creator = playlist['owner']['id'].lower()

        #Filter for non spotify playlists (They generally suck - too many features included)
        if playlist_creator == "spotify" and spotify_enabled is False:
            continue
            
        name_fuzz = fuzz.ratio(playlist_name, command)
        name_pfuzz = fuzz.partial_ratio(playlist_name, command)
        
        #maybe change to and so both have to be horrible matches
        #but the following code should provide only the best
        if name_fuzz <= 70 or name_pfuzz <= 70:
            continue
            
            
        #Given any playlist and creator, returns how many people follow it
        playlist_followers = client.user_playlist(user=playlist_creator, playlist_id=playlist_id)["followers"]["total"]
        
        playlist_likes[playlist_id] = playlist_followers
        playlist_fuzz[playlist_id] = name_fuzz
        #may add pfuzz as another rank to get more accurate
        
        
    if playlist_likes == {}:
        spotify_iter += 1
        if spotify_iter < 2:
            return find_best_playlist(command, client, True, spotify_iter)
        else:
            return "Not Found"
    
    
    else:
        best_id = playlist_ranker(playlist_likes, playlist_fuzz)
        return best_id
    


#Can probably merge this function with best songs since they have similar properties
def find_best_album(command, album_artist, client):
    #Need to fix this to make it better
    
    albums = client.search(q=command, type="album")
    
    album_score = dict()
    
    for album in albums['albums']['items']:
        
        album_name = album['name'].lower()
        album_id = album['id']
        artist = album['artists'][0]['name'].lower()
        
        if album_artist == "":
            artist = ""
            

        album_fuzz = fuzz.ratio(command, album_name)
        artist_fuzz = fuzz.ratio(album_artist, artist)
        artist_pfuzz = fuzz.partial_ratio(album_artist, artist)
        
        #Temp solution
        if fuzz.ratio(command, album_name) < 50:
            continue
        
        if fuzz.ratio(command, album_name) < 70 or fuzz.ratio(album_artist, artist) < 70:
            if fuzz.partial_ratio(album_artist, artist) < 70:
                continue

                
        #If we dont have a artist we go based off popularity (her loss album will return wrong album without popularity)
        if album_artist == "":
            popularity = client.album(album_id)['popularity']
            album_score[(album_fuzz+popularity)] = album_id
        
        #Dont need popularity because the artist name should elimainate all but one
        else:   
            popularity = client.album(album_id)['popularity']
            album_score[(artist_fuzz+popularity)] = album_id
                
    return album_score[max(album_score)]  


def find_user_playlist(client, target_playlist):
    #May need to convert numbers in playlists to the word version (4 -> four)
    
    playlists = dict()
    
    results = spotify_client.current_user_playlists()['items']
    for playlist in results:
        ratio = fuzz.ratio(target_playlist.lower(), playlist['name'].lower())
        
        if ratio >= 70:
            playlists[ratio] = playlist['id']
            
    if playlists == {}:
        return None
        
        
    return playlists[max(playlists)]


def get_liked_songs(client):
    song_ids = []
    
    #Wrap in while loop
    #while length spotify_client.current_user_saved_tracks == 50
    #Then keep doing it but increase offest paramter by 50 each time
    
    for song in spotify_client.current_user_saved_tracks(limit=50)['items']:
        song_id = song['track']['id']
        song_id = "spotify:track:" + song_id
        
        song_ids.append(song_id)
        
        
    random.shuffle(song_ids)
        
    return song_ids


def search_music(command, client):
    if "playlist" in command:
        #Captures only playlists
        command = command.replace(" playlist", "")
        
        id_ = find_user_playlist(client, command)
        
        if id_ is not None:
            return ("spotify:playlist:" + id_)
            
        return ("spotify:playlist:" + find_best_playlist(command, client))
    
    if "album" in command:
        #Captures albums
        command = command.replace(" album", "")
        
        if "by" in command:
            album, artist = get_command_type(command)
            
            return ("spotify:album:" + find_best_album(command, artist, client))
            
        else:
            return ("spotify:album:" + find_best_album(command, "", client))
            
        
        return
        
    if "by" in command:
        #Caputres"No Flockin by Kodak"
        track, artist = get_command_type(command)
        
        return ("spotify:track:" + find_best_song(track, artist, client))
        
    else:
        #captures No Flockin
        return ("spotify:track:" + find_best_song(command, "", client))
        


def play_controller(command, client):
    command = command.replace("play ", "")
    
    if "liked songs" in command or "favorite songs" in command or "favorites" in command:
        #For some reason when you add queueu or do multiple uris it doesnt show on queue on app
        #it shows on phone though
        #spotify_client.start_playback(uris=[liked_songs[0]])
#         for song in liked_songs:
#             client.add_to_queue(song)
        
        liked_songs = get_liked_songs(client)
        spotify_client.start_playback(uris=liked_songs)
        
        return
    
    else:
        uri = search_music(command, client)
        
        if "not found" in uri.lower():
            return "Not Found"
        
        if "track" in uri:
            client.start_playback(uris=[uri])
            
        else:
            client.start_playback(context_uri=uri)
            
            
def queue_controller(command, client):
    #must search for the id then add song to queue
    #EX "Add no flockin by kodak black to queue"
    
    command = re.sub(r'(add|to queue|[^a-zA-Z\s])', '', command, flags=re.IGNORECASE) #removes add to queue words
    
    uri = search_music(command, client)
    spotify_client.add_to_queue(uri=uri)


#Types of commands
# Navbar like commands (pause, resume, skip etc)
# Play songs/albums/playlist commands (play No Flocking by Kodak Black)
#Play liked songs
#Add song to queue
def spotify_controller(command):
    client = create_spotify_connection()
    client = create_spotify_connection()
    
    command = command.lower()
    
    if "play" in command:
        #Send to play controller then search function
        play_controller(command, client)
        return
    
    if "queue" in command:
        #send to queue handler
        queue_controller(command, client)
        return
    
    for action in ["resume", "shuffle", "pause", "next", "back"]:
        if action in command:
            #send to navbar handler
            try:
                navbar_controller(action, client)
                return
                
            except spotipy.SpotifyException as e:
                return
    
    return
        
        
    #If no active devices we must manually restart device
    #To manually restart we can pass in device id to start playback or whatever and restart
#     open_spotify() #Temporary solution to bring spotify to front of screen
#     pyautogui.press('space')

if __name__ == "main":
    spotify_controller(command)

# %%
find_best_song("heart of the projects", "kodak black", spotify_client)
# Out:
# '34KcJ5C4x43LxKoRSSq6hJ'

# %%
#angry yb will accidentally play angry playlist -> must fix


#Works for play best of kodak playlist -> test basic functionality
#Works for play angry youngboy playlist -> tests basic functionality
#Works for play snake jazz playlist -> Tests for super similar playlists - tests ranking algorithm
#Works for play carter playlist -> tests for personal playlists
#Works for play soft jazz playlist -> Tests playlist function to allow spotify playlists to count
spotify_controller("play snake jass playlist")

# %%
search_music("snake jazz playlist", spotify_client)
# Out:
# 'spotify:playlist:4SRHBQH6duxYJh3s92XXHL'

# %%
find_user_playlist(spotify_client, "We Up f57our")

# %%
spotify_client.track("34KcJ5C4x43LxKoRSSq6hJ")['name']
# Out:
# 'Heart Of The Projects'

# %%
find_best_playlist("snake jazz", spotify_client)
# Out:
# '4SRHBQH6duxYJh3s92XXHL'

# %%
find_best_playlist("best of kodak", spotify_client)
# Out:
# '6vrBmDYgfFotABKDg6jC94'

# %%
find_best_playlist("songs that hit like clarity", spotify_client)
# Out:
# '24iyat2KLIzvUSzx4SmXsM'

# %%
spotify_client.start_playback(context_uri="spotify:playlist:34KcJ5C4x43LxKoRSSq6hJ")

# %%
spotify_client.start_playback(uris=["spotify:track:34KcJ5C4x43LxKoRSSq6hJ"])

# %%
vv.index(521)+1
# Out:
# 2

# %%
x
# Out:
# {'4SRHBQH6duxYJh3s92XXHL': 521,
#  '0TWRq6dVjZmEa5HJdxQsh0': 554,
#  '073WEvSX2dOUXa6BCN96RU': 6,
#  '5EZ3dn3Jx8MrSwRHs8XGNA': 5,
#  '0Qa9eMU2GwGrGWnVIMu0qm': 452}

# %%
def playlist_ranker(likes_dict, fuzz_dict):
    likes_rank = sorted(likes_dict.values())[::-1]
    fuzz_rank = sorted(fuzz_dict.values())[::-1]
    
    id_ranks = dict()
    
    for id_ in likes_dict:
        likes = likes_dict[id_]
        l_rank = likes_rank.index(likes) + 1
        
        
        fuzz = fuzz_dict[id_]
        f_rank = fuzz_rank.index(fuzz) + 1
        
        id_ranks[id_] = l_rank + f_rank
        
    return min(id_ranks, key=id_ranks.get)

# %%
playlist_ranker(x, y)
# Out:
# 4SRHBQH6duxYJh3s92XXHL 2 1
# 0TWRq6dVjZmEa5HJdxQsh0 1 1
# 073WEvSX2dOUXa6BCN96RU 4 1
# 5EZ3dn3Jx8MrSwRHs8XGNA 5 1
# 0Qa9eMU2GwGrGWnVIMu0qm 3 1
# '0TWRq6dVjZmEa5HJdxQsh0'

# %%
y
# Out:
# {'4SRHBQH6duxYJh3s92XXHL': 100,
#  '0TWRq6dVjZmEa5HJdxQsh0': 100,
#  '073WEvSX2dOUXa6BCN96RU': 100,
#  '5EZ3dn3Jx8MrSwRHs8XGNA': 100,
#  '0Qa9eMU2GwGrGWnVIMu0qm': 100}

# %%
spotify_client.search(q="soft jazz", type="playlist")
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=soft+jazz&type=playlist&offset=0&limit=10',
#   'items': [{'collaborative': False,
#     'description': 'A soft and slow Jazz soundtrack to play in the background to all your activities.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX949uWWpmTjT'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX949uWWpmTjT',
#     'id': '37i9dQZF1DX949uWWpmTjT',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003222bd32565f7ffcd9b5bafbd',
#       'width': None}],
#     'name': 'Soft Jazz',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY3Mjk1OTYwMCwwMDAwMDAwMGUwMGZhYTY1NzZmMzJkZDE0ZmUxOGE0YzkxMDBhODI1',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX949uWWpmTjT/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX949uWWpmTjT'},
#    {'collaborative': False,
#     'description': 'Soft instrumental Jazz for all your activities.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWV7EzJMK2FUI'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV7EzJMK2FUI',
#     'id': '37i9dQZF1DWV7EzJMK2FUI',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000348e8c41ff383d368f60c09d4',
#       'width': None}],
#     'name': 'Jazz in the Background',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY3Mjk1OTYwMCwwMDAwMDAwMDQxNWMyNTU2ZjdjODdhZjA1OGMxZmU1YzJhODI0ZGMx',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV7EzJMK2FUI/tracks',
#      'total': 468},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWV7EzJMK2FUI'},
#    {'collaborative': False,
#     'description': "Smooth, relaxing as jazz can be, here's the soothing magic in the thick of night from the middle of the light...",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXdwTUxmGKrdN'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdwTUxmGKrdN',
#     'id': '37i9dQZF1DXdwTUxmGKrdN',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000359b115dbc4be98bb2e057910',
#       'width': None}],
#     'name': 'Smooth Jazz',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY3MzM1OTQxMSwwMDAwMDAwMDVmZjc0ZDUwMzFiYmFkNWUxNjAxMDIyYTQxODRmYzJl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdwTUxmGKrdN/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXdwTUxmGKrdN'},
#    {'collaborative': False,
#     'description': 'Relax n chill to the sound of jazz ballads and uplifting soft instrumental music. Miles Davis, Keith Jarrett, Stan Getz, EST, Pat Metheny, SE-Quartet... Cover: Martin Sundström. The playlist is curated by SE-Quartet.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6UxNfr8ORheS4ki0rBL75R'},
#     'href': 'https://api.spotify.com/v1/playlists/6UxNfr8ORheS4ki0rBL75R',
#     'id': '6UxNfr8ORheS4ki0rBL75R',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebbc23aefdb42d18fe12f95719a',
#       'width': None}],
#     'name': 'Soft Instrumental Jazz',
#     'owner': {'display_name': 'Rasmusic',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/44ukgezitncuuksquswxubiux'},
#      'href': 'https://api.spotify.com/v1/users/44ukgezitncuuksquswxubiux',
#      'id': '44ukgezitncuuksquswxubiux',
#      'type': 'user',
#      'uri': 'spotify:user:44ukgezitncuuksquswxubiux'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzY3NCw4MzEyZWRhNDAxZTllMmU1MDQyYzdhYjM3ZGUyMzQzNTkzZDU5YTFl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6UxNfr8ORheS4ki0rBL75R/tracks',
#      'total': 221},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6UxNfr8ORheS4ki0rBL75R'},
#    {'collaborative': False,
#     'description': 'that&#x27;s it. for a classy dinner party, or sleepytime',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3CZVWPrTSapVlQhfCUQF9n'},
#     'href': 'https://api.spotify.com/v1/playlists/3CZVWPrTSapVlQhfCUQF9n',
#     'id': '3CZVWPrTSapVlQhfCUQF9n',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273452bd32b5454a87f36ad8e8cab67616d0000b273cd1ea8639de6d3f827fba218ab67616d0000b273ce4c83c6514608bb1a597c76ab67616d0000b273f8743d2c7812763f7f66e83b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273452bd32b5454a87f36ad8e8cab67616d0000b273cd1ea8639de6d3f827fba218ab67616d0000b273ce4c83c6514608bb1a597c76ab67616d0000b273f8743d2c7812763f7f66e83b',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273452bd32b5454a87f36ad8e8cab67616d0000b273cd1ea8639de6d3f827fba218ab67616d0000b273ce4c83c6514608bb1a597c76ab67616d0000b273f8743d2c7812763f7f66e83b',
#       'width': 60}],
#     'name': 'soft jazzy oldies',
#     'owner': {'display_name': 'אוריין רביב',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/128384674'},
#      'href': 'https://api.spotify.com/v1/users/128384674',
#      'id': '128384674',
#      'type': 'user',
#      'uri': 'spotify:user:128384674'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTAxLDQ3Mjg3ZDIxNGE1MDZiZjZiY2NiN2ZjMDg1ODA2OWFiZjMzMWIyYjA=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3CZVWPrTSapVlQhfCUQF9n/tracks',
#      'total': 90},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3CZVWPrTSapVlQhfCUQF9n'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6SAtboi6MrW1oLwMO6V91c'},
#     'href': 'https://api.spotify.com/v1/playlists/6SAtboi6MrW1oLwMO6V91c',
#     'id': '6SAtboi6MrW1oLwMO6V91c',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebbfb05882c5d94bdc278c82534',
#       'width': None}],
#     'name': 'Soft Morning Jazz',
#     'owner': {'display_name': 'unputdownable',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/unputdownable'},
#      'href': 'https://api.spotify.com/v1/users/unputdownable',
#      'id': 'unputdownable',
#      'type': 'user',
#      'uri': 'spotify:user:unputdownable'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NjMsN2ZmOTQzNTM5ZWUwOWIzYWIwNzU0MWJiZjg2Yjc0MWUzZTZiNjMyYw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6SAtboi6MrW1oLwMO6V91c/tracks',
#      'total': 56},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6SAtboi6MrW1oLwMO6V91c'},
#    {'collaborative': False,
#     'description': 'A playlist made for slow evenings with a glass of wine or a dinner with friends',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4l0OlpjpB75LUIrSRTvAtG'},
#     'href': 'https://api.spotify.com/v1/playlists/4l0OlpjpB75LUIrSRTvAtG',
#     'id': '4l0OlpjpB75LUIrSRTvAtG',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebb7e610cc49b1a75072ac6aa8f',
#       'width': None}],
#     'name': 'Soft jazz evenings',
#     'owner': {'display_name': 'Veronica Nedar',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/veronica.nedar'},
#      'href': 'https://api.spotify.com/v1/users/veronica.nedar',
#      'id': 'veronica.nedar',
#      'type': 'user',
#      'uri': 'spotify:user:veronica.nedar'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzQsMzFjNGIyZjY5YjQxOGQ0Mzk5MDFkZWNiYWQ3MTFkNjgzMTg4OWUzZQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4l0OlpjpB75LUIrSRTvAtG/tracks',
#      'total': 58},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4l0OlpjpB75LUIrSRTvAtG'},
#    {'collaborative': False,
#     'description': 'Warm instrumental versions of your favorite Christmas songs.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWU0r6G8OGirN'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWU0r6G8OGirN',
#     'id': '37i9dQZF1DWU0r6G8OGirN',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003c3196f5150c18abb9ce7db75',
#       'width': None}],
#     'name': 'Cozy Christmas Jazz',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY3MTgwMDI0NSwwMDAwMDAwMDViYjc3MmVjMDFmNGE5ZmFlMzU2ZmEwOWM0NGM1Y2I1',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWU0r6G8OGirN/tracks',
#      'total': 64},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWU0r6G8OGirN'},
#    {'collaborative': False,
#     'description': 'Relaxing Jazz guitar for focus, study or unwinding.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYY963019MQr'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYY963019MQr',
#     'id': '37i9dQZF1DWYY963019MQr',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003b1017062054bc8cc8d5c24e4',
#       'width': None}],
#     'name': 'Soft Jazz Guitar',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY3Mjk1OTYwMCwwMDAwMDAwMGE3ZmU3OWRjZWYzYWEyNDZmNDYxYTA0NWY4NzkwMjgw',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYY963019MQr/tracks',
#      'total': 67},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWYY963019MQr'},
#    {'collaborative': False,
#     'description': 'Soft and cozy vocal and instrumental Jazz. Cover: Melody Gardot',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX52ln8eMkne9'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX52ln8eMkne9',
#     'id': '37i9dQZF1DX52ln8eMkne9',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000031ce01a772c51201e25beeedb',
#       'width': None}],
#     'name': 'Cozy Jazz',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY3MzQyNjcyMiwwMDAwMDAwMDlmNTg5YjgwMWRiNDkzMWJlYmMxNzE1ZmUyY2I5MWQ2',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX52ln8eMkne9/tracks',
#      'total': 150},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX52ln8eMkne9'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=soft+jazz&type=playlist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 4033}}

# %%
queue_controller("add pussy and millions to queue", spotify_client)

# %%
spotify_client.add_to_queue(uri="spotify:track:2KLwPaRDOB87XOYAT2fgxh") #Works when a queue already exits or a next up 
                                                                        #already exists

# %%
import re

command = "Add No Flockin to queue"

# Using re.sub() to remove "add" and "queue"
result = re.sub(r'(add|to queue|[^a-zA-Z\s])', '', command, flags=re.IGNORECASE)

print(result)
# Out:
#  No Flockin

# %%
spotify_controller("pause")

# %%
spotify_controller("play snake jazz playlist")
# Out:
# snake jazz
# lo-fi snake jazz
# snake jazz
# snake jazz
# 🐍 snake jazz 🎷

# %%
try:
    spotify_controller("resume")
except spotipy.SpotifyException as e:
    pass

# %%
find_best_album("heart of the projects", "", spotify_client)
# Out:
# heart of the projects 46
# heart of the projects 1
# heart of the projects 0
# heart of the projects 0
# heart of the projects 0
# the heart of everything 54
# in the heart of the young 46
# heart of stone 64
# heart of this man 41
# '6KFW9lDRKODehZOBESXp3s'

# %%
albums = spotify_client.search(q=command, type="album")

# %%
albums['albums']['items'][0].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
album_id = "5MS3MvWHJ3lOZPLiMxzOU6"

album_data = spotify_client.album(album_id)['popularity']

# %%
album_data
# Out:
# 93

# %%
album_data['popularity']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-298-a31feadc5044> in <module>
# ----> 1 album_data['popularity']
#
# TypeError: 'int' object is not subscriptable

# %%
album_data
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#    'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#    'id': '3TVXtAsR1Inumwj472S9r4',
#    'name': 'Drake',
#    'type': 'artist',
#    'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#    'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#    'id': '1URnnhqYAYcrqrcwql10ft',
#    'name': '21 Savage',
#    'type': 'artist',
#    'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'ET',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'copyrights': [{'text': '© 2022 OVO, under exclusive license to Republic Records, a division of UMG Recordings, Inc',
#    'type': 'C'},
#   {'text': '℗ 2022 OVO, under exclusive license to Republic Records, a division of UMG Recordings, Inc',
#    'type': 'P'}],
#  'external_ids': {'upc': '00602448926227'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/41NvzpIHKpaYHKnh1bF3TN'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/41NvzpIHKpaYHKnh1bF3TN',
#  'id': '41NvzpIHKpaYHKnh1bF3TN',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2730f76fb9c0ab0991c70829a91',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e020f76fb9c0ab0991c70829a91',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048510f76fb9c0ab0991c70829a91',
#    'width': 64}],
#  'label': 'OVO / Republic Records',
#  'name': 'Her Loss',
#  'popularity': 67,
#  'release_date': '2022-11-03',
#  'release_date_precision': 'day',
#  'total_tracks': 16,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/41NvzpIHKpaYHKnh1bF3TN/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 239359,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uWIJXsugQIMaxcYXMxeZV'},
#     'href': 'https://api.spotify.com/v1/tracks/7uWIJXsugQIMaxcYXMxeZV',
#     'id': '7uWIJXsugQIMaxcYXMxeZV',
#     'is_local': False,
#     'name': 'Rich Flex',
#     'preview_url': 'https://p.scdn.co/mp3-preview/7893230dee91d75a29417b63fabf945880f77972?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7uWIJXsugQIMaxcYXMxeZV'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 170501,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VtoDGE3g3P1Bh7kjn6YrC'},
#     'href': 'https://api.spotify.com/v1/tracks/1VtoDGE3g3P1Bh7kjn6YrC',
#     'id': '1VtoDGE3g3P1Bh7kjn6YrC',
#     'is_local': False,
#     'name': 'Major Distribution',
#     'preview_url': 'https://p.scdn.co/mp3-preview/d6e454ad08333b81dc46120075c587c6ccc5c9a9?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1VtoDGE3g3P1Bh7kjn6YrC'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 261543,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2xFZnXTDHOy5BH2gdlBEFi'},
#     'href': 'https://api.spotify.com/v1/tracks/2xFZnXTDHOy5BH2gdlBEFi',
#     'id': '2xFZnXTDHOy5BH2gdlBEFi',
#     'is_local': False,
#     'name': 'On BS',
#     'preview_url': 'https://p.scdn.co/mp3-preview/782bb06ea0789b3c6efe83b7e813aff4c31dabad?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2xFZnXTDHOy5BH2gdlBEFi'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 152961,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/174sDqEJUfQtUqDWZ8rMx6'},
#     'href': 'https://api.spotify.com/v1/tracks/174sDqEJUfQtUqDWZ8rMx6',
#     'id': '174sDqEJUfQtUqDWZ8rMx6',
#     'is_local': False,
#     'name': 'BackOutsideBoyz',
#     'preview_url': 'https://p.scdn.co/mp3-preview/56a4ebe68962f086b8e8c0453c48936b8ac498b5?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:174sDqEJUfQtUqDWZ8rMx6'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 160821,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6pQr9mnsAjBlBBdFLvsgY5'},
#     'href': 'https://api.spotify.com/v1/tracks/6pQr9mnsAjBlBBdFLvsgY5',
#     'id': '6pQr9mnsAjBlBBdFLvsgY5',
#     'is_local': False,
#     'name': 'Privileged Rappers',
#     'preview_url': 'https://p.scdn.co/mp3-preview/49f1bd46207b39caa0fab428f631cf533bf47a6b?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6pQr9mnsAjBlBBdFLvsgY5'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 214588,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/30T2iUZvOVI8mU1KsWvEGY'},
#     'href': 'https://api.spotify.com/v1/tracks/30T2iUZvOVI8mU1KsWvEGY',
#     'id': '30T2iUZvOVI8mU1KsWvEGY',
#     'is_local': False,
#     'name': 'Spin Bout U',
#     'preview_url': 'https://p.scdn.co/mp3-preview/bcd7fbfd8d76016c2db59e1be6ce8b7a134596c5?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:30T2iUZvOVI8mU1KsWvEGY'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 399153,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ILkOgK9OHrrDj8lH8VXes'},
#     'href': 'https://api.spotify.com/v1/tracks/7ILkOgK9OHrrDj8lH8VXes',
#     'id': '7ILkOgK9OHrrDj8lH8VXes',
#     'is_local': False,
#     'name': 'Hours In Silence',
#     'preview_url': 'https://p.scdn.co/mp3-preview/42ea02ea3088f3e2e4801bf391f00642ced800eb?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7ILkOgK9OHrrDj8lH8VXes'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 180098,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7y8oNMMKf0E7pgDeRGbsDf'},
#     'href': 'https://api.spotify.com/v1/tracks/7y8oNMMKf0E7pgDeRGbsDf',
#     'id': '7y8oNMMKf0E7pgDeRGbsDf',
#     'is_local': False,
#     'name': 'Treacherous Twins',
#     'preview_url': 'https://p.scdn.co/mp3-preview/137f0c021fb9ae3830652e0bb691d8557a9fbdc4?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:7y8oNMMKf0E7pgDeRGbsDf'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 236795,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6n849Tolbsyapue50SlLWS'},
#     'href': 'https://api.spotify.com/v1/tracks/6n849Tolbsyapue50SlLWS',
#     'id': '6n849Tolbsyapue50SlLWS',
#     'is_local': False,
#     'name': 'Circo Loco',
#     'preview_url': 'https://p.scdn.co/mp3-preview/5bcbe83ee8f85c77b536d943ef9d63dae7c06ddf?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6n849Tolbsyapue50SlLWS'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#       'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#       'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#       'name': 'Travis Scott',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 242026,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4GLWeHYEynOJA6bGJuw2N9'},
#     'href': 'https://api.spotify.com/v1/tracks/4GLWeHYEynOJA6bGJuw2N9',
#     'id': '4GLWeHYEynOJA6bGJuw2N9',
#     'is_local': False,
#     'name': 'Pussy & Millions (feat. Travis Scott)',
#     'preview_url': 'https://p.scdn.co/mp3-preview/c1bc3f9b4e57430fc3015ef39df32d9d3a104f29?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4GLWeHYEynOJA6bGJuw2N9'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 225439,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7fmu4EBCET6RMnpDp3oZSC'},
#     'href': 'https://api.spotify.com/v1/tracks/7fmu4EBCET6RMnpDp3oZSC',
#     'id': '7fmu4EBCET6RMnpDp3oZSC',
#     'is_local': False,
#     'name': 'Broke Boys',
#     'preview_url': 'https://p.scdn.co/mp3-preview/bfa19f9f3ebd207e1be1f891011d6ac4082450d4?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:7fmu4EBCET6RMnpDp3oZSC'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 356389,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/581wWhlbLcjFibO3wVcOmm'},
#     'href': 'https://api.spotify.com/v1/tracks/581wWhlbLcjFibO3wVcOmm',
#     'id': '581wWhlbLcjFibO3wVcOmm',
#     'is_local': False,
#     'name': 'Middle of the Ocean',
#     'preview_url': 'https://p.scdn.co/mp3-preview/eae9c8187a59eca86e86b97626b0811b50137514?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:581wWhlbLcjFibO3wVcOmm'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 137151,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0qhX394bbCj1YzJGnLxqoP'},
#     'href': 'https://api.spotify.com/v1/tracks/0qhX394bbCj1YzJGnLxqoP',
#     'id': '0qhX394bbCj1YzJGnLxqoP',
#     'is_local': False,
#     'name': 'Jumbotron Shit Poppin',
#     'preview_url': 'https://p.scdn.co/mp3-preview/1b87e2665cbce3189586872fae942b855401c756?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:0qhX394bbCj1YzJGnLxqoP'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 221406,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/16MqFnJTHCWC67pv4ISyKl'},
#     'href': 'https://api.spotify.com/v1/tracks/16MqFnJTHCWC67pv4ISyKl',
#     'id': '16MqFnJTHCWC67pv4ISyKl',
#     'is_local': False,
#     'name': 'More M’s',
#     'preview_url': 'https://p.scdn.co/mp3-preview/38478af19a4e65b161869cafd2949089dade5b71?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:16MqFnJTHCWC67pv4ISyKl'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 178328,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5VfNDZtMfc6OB2ovMSHtnx'},
#     'href': 'https://api.spotify.com/v1/tracks/5VfNDZtMfc6OB2ovMSHtnx',
#     'id': '5VfNDZtMfc6OB2ovMSHtnx',
#     'is_local': False,
#     'name': '3AM on Glenwood',
#     'preview_url': 'https://p.scdn.co/mp3-preview/39ab993d7a9d10c641786acf52a4ed9ed0f7bef4?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:5VfNDZtMfc6OB2ovMSHtnx'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 263987,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/736F3PTZVdvyge2fM8BEhM'},
#     'href': 'https://api.spotify.com/v1/tracks/736F3PTZVdvyge2fM8BEhM',
#     'id': '736F3PTZVdvyge2fM8BEhM',
#     'is_local': False,
#     'name': 'I Guess It’s Fuck Me',
#     'preview_url': 'https://p.scdn.co/mp3-preview/88c89bfa6ff130bd7d5b5bb4cecd4e5cdebefb6c?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:736F3PTZVdvyge2fM8BEhM'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 16},
#  'type': 'album',
#  'uri': 'spotify:album:41NvzpIHKpaYHKnh1bF3TN'}

# %%
#DO NOT FORGET TO ADD PLAYLIST OR ALBUM TO END OF COMMAND
#Add a playlist check tocheck users personal playlists before going to search

spotify_controller("play songs that hit like clarity playlist")

# %%
find_best_album("die lit", "", spotify_client)
# Out:
# die lit 80
# '7dAm8ShwJLFm9SaJ6Yc58O'

# %%
find_best_playlist("Best of Kodak Black", spotify_client)
# Out:
# '6vrBmDYgfFotABKDg6jC94'

# %%
spotify_controller("play liked songs")

# %%
results = spotify_client.search(q="Clarity", type="track")

# %%
find_best_song(results, "Clarity", "", spotify_client)
# Out:
# '60wwxj6Dd9NJlirf84wr2c'

# %%
spotify_client.start_playback(context_uri="spotify:album:6KFW9lDRKODehZOBESXp3s")

# %%
x = get_liked_songs(spotify_client)

# %%
spotify_client.search("No Flockin")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=No+Flockin&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#        'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#        'id': '46SHBwWsqBkxI7EeeBEQG7',
#        'name': 'Kodak Black',
#        'type': 'artist',
#        'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#      'available_markets': ['AD',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'RO',
#       'RS',
#       'RW',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/12YTH28wiBXQ16gvWOCMLU'},
#      'href': 'https://api.spotify.com/v1/albums/12YTH28wiBXQ16gvWOCMLU',
#      'id': '12YTH28wiBXQ16gvWOCMLU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27318f77961dfb9d67895bd9ddb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0218f77961dfb9d67895bd9ddb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485118f77961dfb9d67895bd9ddb',
#        'width': 64}],
#      'name': "No Flockin'",
#      'release_date': '2015-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:12YTH28wiBXQ16gvWOCMLU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#       'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#       'id': '46SHBwWsqBkxI7EeeBEQG7',
#       'name': 'Kodak Black',
#       'type': 'artist',
#       'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 165290,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21503800'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34oWbFBfGEElvgO0a5c9V4'},
#     'href': 'https://api.spotify.com/v1/tracks/34oWbFBfGEElvgO0a5c9V4',
#     'id': '34oWbFBfGEElvgO0a5c9V4',
#     'is_local': False,
#     'name': "No Flockin'",
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c36dd46902b9c2729abbb68c156e205ec290a1d1?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:34oWbFBfGEElvgO0a5c9V4'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#        'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#        'id': '46SHBwWsqBkxI7EeeBEQG7',
#        'name': 'Kodak Black',
#        'type': 'artist',
#        'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#      'available_markets': ['AE',
#       'BF',
#       'BH',
#       'BN',
#       'BY',
#       'CA',
#       'EG',
#       'IN',
#       'JO',
#       'KR',
#       'LB',
#       'MX',
#       'OM',
#       'PS',
#       'QA',
#       'SA',
#       'TN',
#       'US',
#       'UZ'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4jdGBP2hkODEo9ClTURJJz'},
#      'href': 'https://api.spotify.com/v1/albums/4jdGBP2hkODEo9ClTURJJz',
#      'id': '4jdGBP2hkODEo9ClTURJJz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273750107f5b3bd46ab1d53a2c6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02750107f5b3bd46ab1d53a2c6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851750107f5b3bd46ab1d53a2c6',
#        'width': 64}],
#      'name': "No Flockin'",
#      'release_date': '2015-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4jdGBP2hkODEo9ClTURJJz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#       'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#       'id': '46SHBwWsqBkxI7EeeBEQG7',
#       'name': 'Kodak Black',
#       'type': 'artist',
#       'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#     'available_markets': ['AE',
#      'BF',
#      'BH',
#      'BN',
#      'BY',
#      'CA',
#      'EG',
#      'IN',
#      'JO',
#      'KR',
#      'LB',
#      'MX',
#      'OM',
#      'PS',
#      'QA',
#      'SA',
#      'TN',
#      'US',
#      'UZ'],
#     'disc_number': 1,
#     'duration_ms': 165888,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21503801'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Q6BoynOBtVmQcKzkNZkg3'},
#     'href': 'https://api.spotify.com/v1/tracks/2Q6BoynOBtVmQcKzkNZkg3',
#     'id': '2Q6BoynOBtVmQcKzkNZkg3',
#     'is_local': False,
#     'name': "No Flockin'",
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7a882fddef822f68f1b8ad7f36cd39b8f8e2d260?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2Q6BoynOBtVmQcKzkNZkg3'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3FWz3cTvGPfwAGNlLqQaMU'},
#      'href': 'https://api.spotify.com/v1/albums/3FWz3cTvGPfwAGNlLqQaMU',
#      'id': '3FWz3cTvGPfwAGNlLqQaMU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a524e52b333eece5a6e9a67a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a524e52b333eece5a6e9a67a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a524e52b333eece5a6e9a67a',
#        'width': 64}],
#      'name': 'Trap 2022',
#      'release_date': '2022-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:3FWz3cTvGPfwAGNlLqQaMU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#       'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#       'id': '46SHBwWsqBkxI7EeeBEQG7',
#       'name': 'Kodak Black',
#       'type': 'artist',
#       'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 165290,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21503800'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4dGKPHDfhRMJDWlOluM5If'},
#     'href': 'https://api.spotify.com/v1/tracks/4dGKPHDfhRMJDWlOluM5If',
#     'id': '4dGKPHDfhRMJDWlOluM5If',
#     'is_local': False,
#     'name': 'No Flockin',
#     'popularity': 20,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5cada315c5635c97f1bf1429aeaf61da251e0aa?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4dGKPHDfhRMJDWlOluM5If'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1B3QuIsVg9G9onc2vF31at'},
#      'href': 'https://api.spotify.com/v1/albums/1B3QuIsVg9G9onc2vF31at',
#      'id': '1B3QuIsVg9G9onc2vF31at',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273771d57a4cf6b7e3e2372341e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02771d57a4cf6b7e3e2372341e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851771d57a4cf6b7e3e2372341e',
#        'width': 64}],
#      'name': 'Trap Mixtape',
#      'release_date': '2022-08-12',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:1B3QuIsVg9G9onc2vF31at'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#       'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#       'id': '46SHBwWsqBkxI7EeeBEQG7',
#       'name': 'Kodak Black',
#       'type': 'artist',
#       'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 165290,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21503800'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ORJ7Yx45MjkTZXtcc99R3'},
#     'href': 'https://api.spotify.com/v1/tracks/0ORJ7Yx45MjkTZXtcc99R3',
#     'id': '0ORJ7Yx45MjkTZXtcc99R3',
#     'is_local': False,
#     'name': 'No Flockin',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5cada315c5635c97f1bf1429aeaf61da251e0aa?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 21,
#     'type': 'track',
#     'uri': 'spotify:track:0ORJ7Yx45MjkTZXtcc99R3'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0QmwQ5o6U0W5HhUU184oBk'},
#      'href': 'https://api.spotify.com/v1/albums/0QmwQ5o6U0W5HhUU184oBk',
#      'id': '0QmwQ5o6U0W5HhUU184oBk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734402f973df9ca2e13d228625',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024402f973df9ca2e13d228625',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514402f973df9ca2e13d228625',
#        'width': 64}],
#      'name': 'Trap Beats',
#      'release_date': '2022-07-01',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:0QmwQ5o6U0W5HhUU184oBk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#       'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#       'id': '46SHBwWsqBkxI7EeeBEQG7',
#       'name': 'Kodak Black',
#       'type': 'artist',
#       'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 165290,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21503800'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3xjLZHutyKgYldw7odwVWh'},
#     'href': 'https://api.spotify.com/v1/tracks/3xjLZHutyKgYldw7odwVWh',
#     'id': '3xjLZHutyKgYldw7odwVWh',
#     'is_local': False,
#     'name': 'No Flockin',
#     'popularity': 8,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5cada315c5635c97f1bf1429aeaf61da251e0aa?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:3xjLZHutyKgYldw7odwVWh'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QtgPSJPSzcnn7dPZ4VINp'},
#        'href': 'https://api.spotify.com/v1/artists/6QtgPSJPSzcnn7dPZ4VINp',
#        'id': '6QtgPSJPSzcnn7dPZ4VINp',
#        'name': 'King Von',
#        'type': 'artist',
#        'uri': 'spotify:artist:6QtgPSJPSzcnn7dPZ4VINp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5BAggP8hO7VWDSTKkNGyCi'},
#      'href': 'https://api.spotify.com/v1/albums/5BAggP8hO7VWDSTKkNGyCi',
#      'id': '5BAggP8hO7VWDSTKkNGyCi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737155e10eafd9c0aa6ff2a707',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027155e10eafd9c0aa6ff2a707',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517155e10eafd9c0aa6ff2a707',
#        'width': 64}],
#      'name': 'Grandson, Vol. 1',
#      'release_date': '2019-09-20',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5BAggP8hO7VWDSTKkNGyCi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QtgPSJPSzcnn7dPZ4VINp'},
#       'href': 'https://api.spotify.com/v1/artists/6QtgPSJPSzcnn7dPZ4VINp',
#       'id': '6QtgPSJPSzcnn7dPZ4VINp',
#       'name': 'King Von',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QtgPSJPSzcnn7dPZ4VINp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 188400,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1274318'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5bxx3Iz8jfEoGXYJbQH8ZJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5bxx3Iz8jfEoGXYJbQH8ZJ',
#     'id': '5bxx3Iz8jfEoGXYJbQH8ZJ',
#     'is_local': False,
#     'name': 'No Flaws',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6e142f3f1c1a40cdb5aeaee1a24d43315dc93428?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:5bxx3Iz8jfEoGXYJbQH8ZJ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1EguSXeFKLoIMOZByJTqw2'},
#        'href': 'https://api.spotify.com/v1/artists/1EguSXeFKLoIMOZByJTqw2',
#        'id': '1EguSXeFKLoIMOZByJTqw2',
#        'name': 'Slim K',
#        'type': 'artist',
#        'uri': 'spotify:artist:1EguSXeFKLoIMOZByJTqw2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2mBb2N36Y7MTTpScZNlmuM'},
#      'href': 'https://api.spotify.com/v1/albums/2mBb2N36Y7MTTpScZNlmuM',
#      'id': '2mBb2N36Y7MTTpScZNlmuM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737ccf555c8b94cbddad79aead',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027ccf555c8b94cbddad79aead',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517ccf555c8b94cbddad79aead',
#        'width': 64}],
#      'name': 'After School Shit 4 (Chopped Not Slopped Versions)',
#      'release_date': '2018-06-12',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:2mBb2N36Y7MTTpScZNlmuM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1EguSXeFKLoIMOZByJTqw2'},
#       'href': 'https://api.spotify.com/v1/artists/1EguSXeFKLoIMOZByJTqw2',
#       'id': '1EguSXeFKLoIMOZByJTqw2',
#       'name': 'Slim K',
#       'type': 'artist',
#       'uri': 'spotify:artist:1EguSXeFKLoIMOZByJTqw2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 245194,
#     'explicit': True,
#     'external_ids': {'isrc': 'USJ3V1802085'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50xELxTGTxH8cg8CWsMSb1'},
#     'href': 'https://api.spotify.com/v1/tracks/50xELxTGTxH8cg8CWsMSb1',
#     'id': '50xELxTGTxH8cg8CWsMSb1',
#     'is_local': False,
#     'name': 'No Flocking - Chopped Not Slopped Remix',
#     'popularity': 11,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a761cb0ff22897f9477b487a39fef493393f590d?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:50xELxTGTxH8cg8CWsMSb1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iZtZyCzp3LItcw1wtPI3D'},
#        'href': 'https://api.spotify.com/v1/artists/7iZtZyCzp3LItcw1wtPI3D',
#        'id': '7iZtZyCzp3LItcw1wtPI3D',
#        'name': 'Rae Sremmurd',
#        'type': 'artist',
#        'uri': 'spotify:artist:7iZtZyCzp3LItcw1wtPI3D'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6eDx949ONWDCN0O22wFZf7'},
#      'href': 'https://api.spotify.com/v1/albums/6eDx949ONWDCN0O22wFZf7',
#      'id': '6eDx949ONWDCN0O22wFZf7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ca3fb4517ff722918877460',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ca3fb4517ff722918877460',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ca3fb4517ff722918877460',
#        'width': 64}],
#      'name': 'SremmLife',
#      'release_date': '2015-01-06',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6eDx949ONWDCN0O22wFZf7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iZtZyCzp3LItcw1wtPI3D'},
#       'href': 'https://api.spotify.com/v1/artists/7iZtZyCzp3LItcw1wtPI3D',
#       'id': '7iZtZyCzp3LItcw1wtPI3D',
#       'name': 'Rae Sremmurd',
#       'type': 'artist',
#       'uri': 'spotify:artist:7iZtZyCzp3LItcw1wtPI3D'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 231066,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71406157'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2L8cFPItBljPNJgPjTnuIf'},
#     'href': 'https://api.spotify.com/v1/tracks/2L8cFPItBljPNJgPjTnuIf',
#     'id': '2L8cFPItBljPNJgPjTnuIf',
#     'is_local': False,
#     'name': 'No Flex Zone',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8c1a3167cd1394cef662aa5f8b0fcd67c8c4fbce?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2L8cFPItBljPNJgPjTnuIf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/09DD6eRNgOBB7dabBaUloM'},
#        'href': 'https://api.spotify.com/v1/artists/09DD6eRNgOBB7dabBaUloM',
#        'id': '09DD6eRNgOBB7dabBaUloM',
#        'name': 'flowkingrey',
#        'type': 'artist',
#        'uri': 'spotify:artist:09DD6eRNgOBB7dabBaUloM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7cFtHHsyefGWbE1WhgSRhn'},
#      'href': 'https://api.spotify.com/v1/albums/7cFtHHsyefGWbE1WhgSRhn',
#      'id': '7cFtHHsyefGWbE1WhgSRhn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f3b9ab6c0f4ae0903cd45325',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f3b9ab6c0f4ae0903cd45325',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f3b9ab6c0f4ae0903cd45325',
#        'width': 64}],
#      'name': 'Flowkingrey',
#      'release_date': '2021-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:7cFtHHsyefGWbE1WhgSRhn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/09DD6eRNgOBB7dabBaUloM'},
#       'href': 'https://api.spotify.com/v1/artists/09DD6eRNgOBB7dabBaUloM',
#       'id': '09DD6eRNgOBB7dabBaUloM',
#       'name': 'flowkingrey',
#       'type': 'artist',
#       'uri': 'spotify:artist:09DD6eRNgOBB7dabBaUloM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 167187,
#     'explicit': False,
#     'external_ids': {'isrc': 'GX53U2007703'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3E0lc0ITVQmp7E0bia8Hec'},
#     'href': 'https://api.spotify.com/v1/tracks/3E0lc0ITVQmp7E0bia8Hec',
#     'id': '3E0lc0ITVQmp7E0bia8Hec',
#     'is_local': False,
#     'name': 'No tiente',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d70db13a77a3b8065557eb4e307767eafe4fa851?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3E0lc0ITVQmp7E0bia8Hec'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Nf5yishRW9Ye174sJISkg'},
#        'href': 'https://api.spotify.com/v1/artists/5Nf5yishRW9Ye174sJISkg',
#        'id': '5Nf5yishRW9Ye174sJISkg',
#        'name': 'London On Da Track',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Nf5yishRW9Ye174sJISkg'}],
#      'available_markets': ['AD',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KZ',
#       'LA',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'RO',
#       'RS',
#       'RW',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4eGt5BVGxdgwgYD6yxXUSD'},
#      'href': 'https://api.spotify.com/v1/albums/4eGt5BVGxdgwgYD6yxXUSD',
#      'id': '4eGt5BVGxdgwgYD6yxXUSD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e38152f82a1814685713f67d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e38152f82a1814685713f67d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e38152f82a1814685713f67d',
#        'width': 64}],
#      'name': 'No Flag (feat. Nicki Minaj, 21 Savage & Offset)',
#      'release_date': '2017-08-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4eGt5BVGxdgwgYD6yxXUSD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Nf5yishRW9Ye174sJISkg'},
#       'href': 'https://api.spotify.com/v1/artists/5Nf5yishRW9Ye174sJISkg',
#       'id': '5Nf5yishRW9Ye174sJISkg',
#       'name': 'London On Da Track',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Nf5yishRW9Ye174sJISkg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DdkRBBYG6Yk9Ka8tdJ9BW'},
#       'href': 'https://api.spotify.com/v1/artists/4DdkRBBYG6Yk9Ka8tdJ9BW',
#       'id': '4DdkRBBYG6Yk9Ka8tdJ9BW',
#       'name': 'Offset',
#       'type': 'artist',
#       'uri': 'spotify:artist:4DdkRBBYG6Yk9Ka8tdJ9BW'}],
#     'available_markets': ['AD',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KZ',
#      'LA',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RS',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 212383,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC11702107'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1tyjWMMINb9S0YBynTvJ7s'},
#     'href': 'https://api.spotify.com/v1/tracks/1tyjWMMINb9S0YBynTvJ7s',
#     'id': '1tyjWMMINb9S0YBynTvJ7s',
#     'is_local': False,
#     'name': 'No Flag (feat. Nicki Minaj, 21 Savage & Offset)',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d4cda60b566079dc223f9c356051bfaaaef9746c?cid=7cf09e11b901468b8fa62e287678f4c9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1tyjWMMINb9S0YBynTvJ7s'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=No+Flockin&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 472}}

# %%
for _ in spotify_client.search("Her Loss", type="album")['albums']['items']:
    print(_)
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'}, 'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft', 'id': '1URnnhqYAYcrqrcwql10ft', 'name': '21 Savage', 'type': 'artist', 'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5MS3MvWHJ3lOZPLiMxzOU6'}, 'href': 'https://api.spotify.com/v1/albums/5MS3MvWHJ3lOZPLiMxzOU6', 'id': '5MS3MvWHJ3lOZPLiMxzOU6', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27302854a7060fccc1a66a4b5ad', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0202854a7060fccc1a66a4b5ad', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485102854a7060fccc1a66a4b5ad', 'width': 64}], 'name': 'Her Loss', 'release_date': '2022-11-04', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:5MS3MvWHJ3lOZPLiMxzOU6'}
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'}, 'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft', 'id': '1URnnhqYAYcrqrcwql10ft', 'name': '21 Savage', 'type': 'artist', 'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/41NvzpIHKpaYHKnh1bF3TN'}, 'href': 'https://api.spotify.com/v1/albums/41NvzpIHKpaYHKnh1bF3TN', 'id': '41NvzpIHKpaYHKnh1bF3TN', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2730f76fb9c0ab0991c70829a91', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e020f76fb9c0ab0991c70829a91', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048510f76fb9c0ab0991c70829a91', 'width': 64}], 'name': 'Her Loss', 'release_date': '2022-11-03', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:41NvzpIHKpaYHKnh1bF3TN'}
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'}, 'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK', 'id': '5f7VJjfbwm532GiveGC0ZK', 'name': 'Lil Baby', 'type': 'artist', 'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/2gxdY1p1speqMXQVQYXgij'}, 'href': 'https://api.spotify.com/v1/albums/2gxdY1p1speqMXQVQYXgij', 'id': '2gxdY1p1speqMXQVQYXgij', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27306c1d810ee3d96cb5cf8c435', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0206c1d810ee3d96cb5cf8c435', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485106c1d810ee3d96cb5cf8c435', 'width': 64}], 'name': "It's Only Me", 'release_date': '2022-10-14', 'release_date_precision': 'day', 'total_tracks': 23, 'type': 'album', 'uri': 'spotify:album:2gxdY1p1speqMXQVQYXgij'}
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BG', 'BH', 'BI', 'BJ', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/2z3NlPY0n0gHJPCPqrzA6V'}, 'href': 'https://api.spotify.com/v1/albums/2z3NlPY0n0gHJPCPqrzA6V', 'id': '2z3NlPY0n0gHJPCPqrzA6V', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27358599e61e8a0487443d31bb6', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0258599e61e8a0487443d31bb6', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485158599e61e8a0487443d31bb6', 'width': 64}], 'name': 'Sneakin’', 'release_date': '2016-10-24', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:2z3NlPY0n0gHJPCPqrzA6V'}
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nvWOyAkfNgVLKESq4fOj2'}, 'href': 'https://api.spotify.com/v1/artists/5nvWOyAkfNgVLKESq4fOj2', 'id': '5nvWOyAkfNgVLKESq4fOj2', 'name': 'Montell Fish', 'type': 'artist', 'uri': 'spotify:artist:5nvWOyAkfNgVLKESq4fOj2'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3q6BNwqgHKVzXzAv2ZV6tD'}, 'href': 'https://api.spotify.com/v1/albums/3q6BNwqgHKVzXzAv2ZV6tD', 'id': '3q6BNwqgHKVzXzAv2ZV6tD', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f46e995aa84c6eb1080100a4', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f46e995aa84c6eb1080100a4', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f46e995aa84c6eb1080100a4', 'width': 64}], 'name': 'Her Love Still Haunts Me Like a Ghost', 'release_date': '2022-10-28', 'release_date_precision': 'day', 'total_tracks': 7, 'type': 'album', 'uri': 'spotify:album:3q6BNwqgHKVzXzAv2ZV6tD'}
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4efMdlcyx58Y9YJCS9oYPo'}, 'href': 'https://api.spotify.com/v1/artists/4efMdlcyx58Y9YJCS9oYPo', 'id': '4efMdlcyx58Y9YJCS9oYPo', 'name': 'Gemini Tha Artist', 'type': 'artist', 'uri': 'spotify:artist:4efMdlcyx58Y9YJCS9oYPo'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/7j0ksXh5zjpHjVEEoQJJ0x'}, 'href': 'https://api.spotify.com/v1/albums/7j0ksXh5zjpHjVEEoQJJ0x', 'id': '7j0ksXh5zjpHjVEEoQJJ0x', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2731ee217bfc2ba7202cd675de5', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e021ee217bfc2ba7202cd675de5', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048511ee217bfc2ba7202cd675de5', 'width': 64}], 'name': 'Her Loss', 'release_date': '2022-11-11', 'release_date_precision': 'day', 'total_tracks': 3, 'type': 'album', 'uri': 'spotify:album:7j0ksXh5zjpHjVEEoQJJ0x'}
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4JAIvx8vd1sMssmNTcwnPX'}, 'href': 'https://api.spotify.com/v1/artists/4JAIvx8vd1sMssmNTcwnPX', 'id': '4JAIvx8vd1sMssmNTcwnPX', 'name': 'lofi.remixes', 'type': 'artist', 'uri': 'spotify:artist:4JAIvx8vd1sMssmNTcwnPX'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zfNkbfXyVpesD3S0XFKB8'}, 'href': 'https://api.spotify.com/v1/artists/0zfNkbfXyVpesD3S0XFKB8', 'id': '0zfNkbfXyVpesD3S0XFKB8', 'name': 'golden era', 'type': 'artist', 'uri': 'spotify:artist:0zfNkbfXyVpesD3S0XFKB8'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3EYDbsjhE3t9dJbox4h3b2'}, 'href': 'https://api.spotify.com/v1/albums/3EYDbsjhE3t9dJbox4h3b2', 'id': '3EYDbsjhE3t9dJbox4h3b2', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2735c9273f83fdefb014149cd28', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e025c9273f83fdefb014149cd28', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048515c9273f83fdefb014149cd28', 'width': 64}], 'name': 'Her Loss (lofi version)', 'release_date': '2022-12-02', 'release_date_precision': 'day', 'total_tracks': 5, 'type': 'album', 'uri': 'spotify:album:3EYDbsjhE3t9dJbox4h3b2'}
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3w3vphGf3Rt6yO86jIKB4D'}, 'href': 'https://api.spotify.com/v1/artists/3w3vphGf3Rt6yO86jIKB4D', 'id': '3w3vphGf3Rt6yO86jIKB4D', 'name': 'Elias.', 'type': 'artist', 'uri': 'spotify:artist:3w3vphGf3Rt6yO86jIKB4D'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3rSFUVjnKKtd57XgfOPeuc'}, 'href': 'https://api.spotify.com/v1/albums/3rSFUVjnKKtd57XgfOPeuc', 'id': '3rSFUVjnKKtd57XgfOPeuc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273e3c34f34f60115b85cf39384', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02e3c34f34f60115b85cf39384', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851e3c34f34f60115b85cf39384', 'width': 64}], 'name': 'her loss', 'release_date': '2023-01-06', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:3rSFUVjnKKtd57XgfOPeuc'}
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7RZ31TRPVadSFVy1o8os'}, 'href': 'https://api.spotify.com/v1/artists/3Y7RZ31TRPVadSFVy1o8os', 'id': '3Y7RZ31TRPVadSFVy1o8os', 'name': 'H.E.R.', 'type': 'artist', 'uri': 'spotify:artist:3Y7RZ31TRPVadSFVy1o8os'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/2pPGkrEYiHUmqSyg3sAGII'}, 'href': 'https://api.spotify.com/v1/albums/2pPGkrEYiHUmqSyg3sAGII', 'id': '2pPGkrEYiHUmqSyg3sAGII', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2739276b0040c00070f5811019e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e029276b0040c00070f5811019e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048519276b0040c00070f5811019e', 'width': 64}], 'name': 'Damage', 'release_date': '2020-10-21', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:2pPGkrEYiHUmqSyg3sAGII'}
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7RZ31TRPVadSFVy1o8os'}, 'href': 'https://api.spotify.com/v1/artists/3Y7RZ31TRPVadSFVy1o8os', 'id': '3Y7RZ31TRPVadSFVy1o8os', 'name': 'H.E.R.', 'type': 'artist', 'uri': 'spotify:artist:3Y7RZ31TRPVadSFVy1o8os'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/77PRAIWX97p7rnEwDjaG3U'}, 'href': 'https://api.spotify.com/v1/albums/77PRAIWX97p7rnEwDjaG3U', 'id': '77PRAIWX97p7rnEwDjaG3U', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27350dab2850cde7ba0aee473d2', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0250dab2850cde7ba0aee473d2', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485150dab2850cde7ba0aee473d2', 'width': 64}], 'name': 'Hard Place', 'release_date': '2018-11-02', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:77PRAIWX97p7rnEwDjaG3U'}

# %%
for _ in spotify_client.current_user_saved_tracks(limit=50)['items']:
    print(_['track']['id'])
    break
# Out:
# 57bgtoPSgt236HzfBOd8kj

# %%
id_ = restart_device(spotify_client)

# %%
spotify_client.start_playback(uris = ["spotify:track:57bgtoPSgt236HzfBOd8kj"])

# %%
spotify_client = create_spotify_connection()

# %%
open_spotify()
# Out:
# 0xc10a7a

# %%
spotify_client.devices()['devices']
# Out:
# [{'id': '88310545629f44b38748a461c86e5fc2679b828d',
#   'is_active': False,
#   'is_private_session': False,
#   'is_restricted': False,
#   'name': 'SEBASTIAN-PC',
#   'type': 'Computer',
#   'volume_percent': 72}]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sbuca\\Documents\\pierre\\music_files'

# %%
get_config_file()
# Out:
# 'C:\\Users\\sbuca\\Documents\\pierre\\music_files\\spotify_config.ini'

# %%
def get_open_apps():
    apps = {}
    
    def winEnumHandler( hwnd, ctx,):
        if win32gui.IsWindowVisible( hwnd ):
            #int(hex(hwnd)) converts hex back to int
            apps[win32gui.GetWindowText( hwnd )] = hex(hwnd)

    win32gui.EnumWindows( winEnumHandler, None )
    
    return apps

# %%
get_open_apps()
# Out:
# {'': '0x10744',
#  'spotify - Jupyter Notebook - Google Chrome': '0x3d0d0c',
#  'Barbarian Full Movie Watch Online 123Movies - Google Chrome': '0x13d0976',
#  'Downloads': '0x804c6',
#  'Model Helps User - Google Chrome': '0x2044a',
#  'Settings': '0xa30c6e',
#  'Windows Input Experience': '0x5026e',
#  'APP Center': '0x10288',
#  'NVIDIA GeForce Overlay': '0x2015c',
#  'python - How to get a list of the name of every open window? - Stack Overflow - Google Chrome': '0x20408',
#  'Command Prompt': '0x3d0c12',
#  'Steam': '0x11087c',
#  'model_data.xlsx - Excel': '0x1013c0',
#  'YouTube - Google Chrome': '0x50fae',
#  'Anaconda Navigator': '0x580da6',
#  'Inbox (395) - sbucarion1@babson.edu - Babson College Mail - Google Chrome': '0x4e1066',
#  'Spotify Premium': '0x331306',
#  'Program Manager': '0x101d8'}

# %%
get_open_apps()
